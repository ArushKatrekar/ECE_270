# %% [markdown]
# # Lab Assignment 3:
#
# ### Academic Integrity Statement:
# By typing my name, below, I hereby certify that the work on this lab is my own and that I have not copied the work of any other student (past or present) while completing it. I understand that if I fail to honor this agreement, I will receive a score of ZERO for the lab, a one letter drop in my final course grade, and be subject to possible disciplinary action.
#
# I also understand that I am to use only my own hardware for this and every other lab and not share it with any other student. I have used only my own hardware for this lab (except when explicitly permitted otherwise by the course staff). If a discovery is made otherwise, I will receive a zero for this lab.

# %%
student_username = "akatreka" # Replace with your username
student_name = "Arush Katrekar" # Replace with your name

# %% [markdown]
# <!-- ## **74HC14 Parameters**   -->
# ### **1. Reading device characterisics from datasheets — Transition Thresholds [6 points]**
#
# Read the table in the **74HC14** datasheet section 13 (Transfer characteristics) very carefully. What would you expect the following values to be for a 74HC14 (not a 74HCT14) with a VCC of 4.5V, and running at an ambient temperature of 25 °C?
#
# #### Q. Enter the minimum, typical,  and maximum V<sub>T+</sub> values (V)

# %%
vt_plus_min = 1.7  # Replace 0.0 with minimum value for V_T_+ in Volts
vt_plus_typical = 2.38  # Replace 0.0 with typical value for V_T_+ in Volts
vt_plus_max = 3.15  # Replace 0.0 with maximum value for V_T_+ in Volts

# %% [markdown]
# #### Q. Enter the minimum, typical,  and maximum  V<sub>T-</sub> values (V)

# %%
vt_minus_min = 0.9  # Replace 0.0 with minimum value for V_T_- in Volts
vt_minus_typical = 1.4  # Replace 0.0 with typical value for V_T_- in Volts
vt_minus_max = 2.0  # Replace 0.0 with maximum value for V_T_- in Volts

# %% [markdown]
# **Note: 74HC04 datasheet has no transfer characteristics section. Normal inverter has standard input voltage thresholds.**
#
#
# ### **2. Reading device characterisics from datasheets — Timing Parameters [8 points]**
# Read the table in the **74HC86** datasheet section 10 (Dynamic characteristics) very carefully. In particular, you should pay close attention to footnotes [1] and [2]. What would you *expect* the following values to be for a **74HC86** (not a *74HCT86*) with a VCC of 4.5V, and running at an ambient temperature of 25 °C?
#
# From section 10 (Dynamic characteristics)
# #### Enter the typical and maximum transition times for the following:
#  - Transition time high to low (t<sub>THL</sub> values in ns)
#  - Transition time for low to high (t<sub>TLH</sub> values in ns)
#  - Propagation delay for high to low (t<sub>PHL</sub> values in ns)
#  - Propagation delay for low to high (t<sub>PLH</sub> values in ns)

# %%
# Transition time high to low:
t_THL_typical = 7  # Replace 0.0 with the typical value for the transition time high to low
t_THL_max = 15      # Replace 0.0 with the maximum value for the transition time high to low

# Transition time low to high:
t_TLH_typical = 7  # Replace 0.0 with the typical value for the transition time low to high
t_TLH_max = 15      # Replace 0.0 with the maximum value for the transition time low to high

# propagation Delay high to low:
pd_THL_typical = 14  # Replace 0.0 with the typical value for the propagation Delay high to low
pd_THL_max = 24      # Replace 0.0 with the maximum value for the propagation Delay high to low

# propagation Delay low to high:
pd_TLH_typical = 14  # Replace 0.0 with the typical value for the propagation Delay low to high
pd_TLH_max = 24      # Replace 0.0 with the maximum value for the propagation Delay low to high

# %% [markdown]
# ### **3. Estimating device parametrics [4 points]**
# Consider the diagram below and answer the following questions. _Round your answers to the nearest 0.1 ns._
#
# Q. Use the **10%/90% rule** to estimate rise and fall times. I.e., measure the rise time of the output as the time needed to go from the 10% level to the 90% level. (You would find that the oscilloscopes in the lab have a way of estimating this automatically.)
#
# For the propagation delay, it is always important to remember to measure it as the time from the center of the transition on the input **that caused the output transition** to the time of the center of the transition on the output that it causes. The propagation delay is always specified by the transition on the output. For instance, **t<sub>TPHL</sub>**, for a NAND gate, is the delay between an input transition and a **high-to-low** transition of the output.
#
# What if there are two input transitions close to one another? Which input transition causes the corresponding output transition? You need to think that through and pick the right one to know how to estimate the timing.
#
# ![image.png](attachment:image.png)

# %%
# Measured Transition time high to low from the graph:
t_THL_graph = 1.6   # Replace 0.0 with the transition time high to low from the graph

# Measured Transition time low to high from the graph:
t_TLH_graph = 3.2   # Replace 0.0 with the transition time low to high from the graph

# Measured propagation Delay high to low from the graph:
pd_THL_graph = 7  # Replace 0.0 with the propagation Delay high to low from the graph

# Measured propagation Delay low to high from the graph:
pd_TLH_graph = 9  # Replace 0.0 with the propagation Delay low to high from the graph

# %% [markdown]
# ### **4. Predicting path delays [7 points]**
#
# <!--  -->
# Let's assume that, as is the case with most CMOS logic gates these days, t<sub>PHL</sub> = t<sub>PLH</sub>. Look up the typical propagation delays for the **74HC00 NAND gate**, the **74HC86 XOR gate** and the **74HC02 NOR gate**. Assume that the operating voltage is 4.5 V and the ambient temperature is 25 °C. For each of the circuit diagrams, what is the expected total propagation delay from A to Z when the other inputs to the gates are in a state that a change in A will cause a change in Z?
#
# Let's be clear here: There are some gate inputs that look like they're unconnected. You should assume that they are connected to some value that will allow a transition on the other input to effect a transition of the output pin. The goal is not to analyze the logical implications, but rather to compute the timing between A and Z. Each transition on A will, eventually, cause a transition on Z. How long will it take?
# <!--  -->
#
# #### Enter propagation delay for circuit 4.1 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_1 = 18  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.2 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_2 = 23  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.3 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_3 = 23  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.4 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_4 = 18  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.5 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_5 = 32  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.6 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_6 = 32  # Replace 0.0 with calculated value

# %% [markdown]
# #### Enter propagation delay for circuit 4.7 below in (ns)
# ![image.png](attachment:image.png)

# %%
delay_4_7 = 51  # Replace 0.0 with calculated value

# %% [markdown]
# ---

# %% [markdown]
# ## **Post Construction Steps**
# Complete the below section only after you have completed all the tasks in lab3.md.

# %% [markdown]
# #### **Task 1: Measure threshold voltages of an **74HC04** inverter**
# Refer to Step 1 of `lab3.md` and confirm you have completed the Step deliverables.
#
# Enter **your** measured transition voltage values for V<sub>T\+</sub> and V<sub>T-</sub> from Step 1:

# %%
step_1_measured_VT_plus = 1.57  # Replace with VT + measured value
step_1_measured_VT_minus = 1.28   # Replace with VT - measured value

# %% [markdown]
# #### **Task 2: Measure threshold voltages of a 74HC14 Schmitt-trigger inverter**
#
# Refer to Step 2 of `lab3.md` and confirm you have completed the Step deliverables.
#
# Enter **your** measured transition voltage values for V<sub>T\+</sub> and V<sub>T-</sub> from Step 2:

# %%
step_2_measured_VT_plus = 1.63  # Replace with VT + measured value
step_2_measured_VT_minus = 1.21  # Replace with VT - measured value

# %% [markdown]
# #### **Task 3a: Propagation Delay Measurements**
# Reminder you need to complete the following before continuing on:
#
# Refer to `Submission of Logic tool trace` in `lab3.md` and make sure you have completed all the the instructions regarding that step. You will use the logic trace from that step to complete `Task 3b` below. Ensure your captured from the AD2 Logic tool that shows the following signals:
#
# - **DIO 0**
# - **DIO 11**
# - **DIO 8**
# - **DIO 9**
# - **DIO 10**
#
# while the operating voltage is 2.0 V.
#
# Here are the rules for AD2 files:
# - It must be an export from the AD2 — not a screen capture.
# - It must be in PNG format.
# - The export must show the date, time, and your AD2 serial number.
# - Don't make WaveForms full-screen. Keep the window size down to around 800x600. Larger window sizes result in a larger export file. Uploads that are too large will not be accepted.
#
# Refer to `Submission Instructions` in the lab document `lab3.md` for submitting the captured image and csv data.

# %% [markdown]
# ### **Task 3b: Record Measured Values**
#
# Enter the values you observed in the logic analyzer trace. The slope shows the ambiguity of measurement due to the slow sample rate of the AD2, but it shows you the minimum and maximum time of the transition. Also consider the typical propagation delay for 74HC00 NAND gates and 74HC86 XOR gates at an ambient temperature of 25°C. **Compute the predicted path delay from A0 to the selected measurement point.** Remember the rules for AD2 file exports.
#
# Enter your readings for the following below:
#
# Make sure to set the supply voltage at 2.0V for these measurements.
#
# | Measurement                     | Minimum (ns) | Maximum (ns) | Predicted (ns) |
# |---------------------------------|--------------|--------------|----------------|
# | Time of propagation from A0 to Cout0 | ________     | ________     | ________        |
# | Time of propagation from A0 to S0    | ________     | ________     | ________        |
# | Time of propagation from A0 to S1    | ________     | ________     | ________        |
# | Time of propagation from A0 to S2    | ________     | ________     | ________        |

# %%
# Enter your values in the space below:

minimum_a0_to_cout0 = 30.587   # Replace with your measured value
minimum_a0_to_s0 = 20.627  # Replace with your measured value
minimum_a0_to_s1 = 40.503  # Replace with your measured value
minimum_a0_to_s2 = 59.87  # Replace with your measured value

maximum_a0_to_cout0 = 49.386  # Replace with your measured value
maximum_a0_to_s0 = 39.441  # Replace with your measured value
maximum_a0_to_s1 = 59.657  # Replace with your measured value
maximum_a0_to_s2 = 69.278  # Replace with your measured value

predicted_a0_to_cout0 = 50  # Replace with calculated value
predicted_a0_to_s0 = 78  # Replace with calculated value
predicted_a0_to_s1 = 89  # Replace with calculated value
predicted_a0_to_s2 = 100  # Replace with calculated value

# %% [markdown]
# #### Upload AD2 Acquisition Data
# Refer to `Submission of Logic tool trace` in `lab3.md` and make sure to submit the CSV data you have i.e `logic_trace_data.csv`, as we use the uploaded CSV data to grade Step 3b. Please make sure to upload the propagation delays correctly (from the same screen where you took the screenshot) so we can correctly grade your work.
#
# If you needed to do something strange to wire your circuit, let us know here. For instance, if you didn't have two 74HC00 quad NAND chips and you had to use a 74HC08 AND and 74HC04 inverter to implement the extra NAND gates, that will affect your propagation delays. You should let us know about that here. If you implemented the circuit as described, you can leave this blank or leave it as "REPLACE_REASONING_FOR_STRANGE_WIRING".

# %%
# Replace if you had to do something strange to wire your circuit:
reason = " "

# %% [markdown]
# #### Task 3c: Measured Path delay between A0 and S2
# You need complete the question below. Confirm you have completed the Step deliverables in Step 4 of `lab3.md`.
#
# Reminder: Go to the lab document `lab3.md` and make sure you have submitted `propagation_delay.png` as per the `Submission Instructions`.
#
# Remember the captured image from the oscilloscope should show the propagation delay between A0 and S2 as explained in the lab instructions.
#
# **Q. What value did you measure for the path delay between A0 and S2?**

# %%
# Replace with your measured propagation delay
path_delay_a0_to_S2 = 53.2

# %%
# *DO NOT UNDER ANY circumstance edit the last cell in that file you WILL be given a ZERO.
import json

variables_json = json.dumps({
    "student_username": student_username,
    "student_name": student_name,
    "vt_plus": {
        "min": vt_plus_min,
        "typical": vt_plus_typical,
        "max": vt_plus_max
    },
    "vt_minus": {
        "min": vt_minus_min,
        "typical": vt_minus_typical,
        "max": vt_minus_max
    },
    "t_thl": {
        "typical": t_THL_typical,
        "max": t_THL_max
    },
    "t_tlh": {
        "typical": t_TLH_typical,
        "max": t_TLH_max
    },
    "t_phl": {
        "typical": pd_THL_typical,
        "max": pd_THL_max
    },
    "t_plh": {
        "typical": pd_TLH_typical,
        "max": pd_TLH_max
    },
    "t_graph": {
        "thl": t_THL_graph,
        "tlh": t_TLH_graph,
        "phl": pd_THL_graph,
        "plh": pd_TLH_graph
    },
    "delays": {
        "4_1": delay_4_1,
        "4_2": delay_4_2,
        "4_3": delay_4_3,
        "4_4": delay_4_4,
        "4_5": delay_4_5,
        "4_6": delay_4_6,
        "4_7": delay_4_7
    },
    "step_1": {
        "VT_plus": step_1_measured_VT_plus,
        "VT_minus": step_1_measured_VT_minus
    },
    "step_2": {
        "VT_plus": step_2_measured_VT_plus,
        "VT_minus": step_2_measured_VT_minus
    },
    "step_3b": {
        "minimum": {
            "a0_to_cout0": minimum_a0_to_cout0,
            "a0_to_s0": minimum_a0_to_s0,
            "a0_to_s1": minimum_a0_to_s1,
            "a0_to_s2": minimum_a0_to_s2
        },
        "maximum": {
            "a0_to_cout0": maximum_a0_to_cout0,
            "a0_to_s0": maximum_a0_to_s0,
            "a0_to_s1": maximum_a0_to_s1,
            "a0_to_s2": maximum_a0_to_s2
        },
        "predicted": {
            "a0_to_cout0": predicted_a0_to_cout0,
            "a0_to_s0": predicted_a0_to_s0,
            "a0_to_s1": predicted_a0_to_s1,
            "a0_to_s2": predicted_a0_to_s2
        }
    },
    "step_3c": {
        "path_delay_a0_to_S2": path_delay_a0_to_S2
    }
}, indent=4)
with open('student_submission.json', 'w') as f:
    f.write(variables_json)

print(variables_json)
# Out:
# {
#     "student_username": "akatreka",
#     "student_name": "Arush Katrekar",
#     "vt_plus": {
#         "min": 1.7,
#         "typical": 2.38,
#         "max": 3.15
#     },
#     "vt_minus": {
#         "min": 0.9,
#         "typical": 1.4,
#         "max": 2.0
#     },
#     "t_thl": {
#         "typical": 7,
#         "max": 15
#     },
#     "t_tlh": {
#         "typical": 7,
#         "max": 15
#     },
#     "t_phl": {
#         "typical": 14,
#         "max": 24
#     },
#     "t_plh": {
#         "typical": 14,
#         "max": 24
#     },
#     "t_graph": {
#         "thl": 1.6,
#         "tlh": 3.2,
#         "phl": 7,
#         "plh": 9
#     },
#     "delays": {
#         "4_1": 18,
#         "4_2": 23,
#         "4_3": 23,
#         "4_4": 18,
#         "4_5": 32,
#         "4_6": 32,
#         "4_7": 51
#     },
#     "step_1": {
#         "VT_plus": 1.57,
#         "VT_minus": 1.28
#     },
#     "step_2": {
#         "VT_plus": 1.63,
#         "VT_minus": 1.21
# ...
