# %% [markdown]
# # Lab 0: Student Information
#
# * * *
# **Purpose:** This is an example notebook that demonstrates the submission format for future labs. Please complete this simple form so we can learn a bit about you and ensure you understand how to submit assignments in this course.
#
# * * *
#
# ## Academic Honesty Statement
#
# By typing my name below, I hereby certify that the work on this assignment is my own and that I have not copied the work of any other student (past or present) while completing it. I understand that if I fail to honor this agreement, I will receive a score of ZERO for the assignment, a one letter drop in my final course grade, and be subject to possible disciplinary action.

# %% [markdown]
# ### Student Information
#
# Please provide your name and username below. Make sure your name matches your official university records.

# %%
username = "akatreka" # Your Purdue username (e.g., jsmith)
name = "Arush Rahul Katrekar" # Your full name (e.g., John Smith)

# %% [markdown]
# ## Github and Lab Materials Form
# **(Mandatory! You must complete these steps to continue with the course)**
#
# 1. Submit your GitHub username linked to your Purdue email account:
#
#     **By now you should have completed the Github form to access this repository.** This should be your GitHub account made with your Purdue email. If you do not have one a Github account associated with your Purdue email please make one, and resubmit the form (you may have to contact the owner of the form or use a different gmail). If you do not do complete this promptly and correctly, you may not have access to material later in the semester.
#
#     Should you need to resubmit, notify the teaching staff and we will grant you access to resubmit the form. Google form in case you need to re-submit GitHub username [here](https://forms.gle/NKCu4c7kxah3SoKh9).
#
# 2. Confirm you have all the lab materials:
#
#     Confirm you have all the required lab materials you need to continue with this class. Make sure you have these by the time the breadboarding labs start.
#
#     Google form confirming you have all the required lab materials [here](https://forms.gle/Lk4JRcS7hNtgJYJK7)

# %% [markdown]
# ## Classroom Accommodations

# %% [markdown]
# ### Are you colorblind?
# There's nothing wrong with being colorblind, but the course staff may have some questions about your perception of RGB LEDs. We want to make sure that everyone is able to easily view signals and controls. If you're colorblind, you can help us identify and avoid any problems that students might have with the lab hardware. (In the interest of not discriminating against anyone, you're not required to tell us if you're colorblind---only if you want to help us out.)
# If you are colorblind you will want to double check the value of every resistor you use with a multimeter to verify you are using the correct resistance.

# %%
colorblind= "No" # Answer with "Yes" or "No"

# %% [markdown]
# ### Are you left handed?
# To help us prepare for midterm exams, please indicate whether you need a left-handed desk. Answer with either "Yes" or "No".

# %%
left_handed_desk = "No" # Answer with "Yes" or "No"

# %% [markdown]
# ## Check Your Policy Knowledge [20 points]
# Read the lab rules in the references folder `refs/` [here](../../refs/lab-rules.pdf).
#
# Answer True or False for each of the statements in the code cell below. (Even if it wasn't explicitly stated in the lab rules, just put an answer. There's no penalty for getting these wrong, so just try one or the other so you know what the correct answer is.)  Make sure to write "True" or "False" in the space provided for the following questions. An example question is also given below to demonstrate how we expect you to type your answer.

# %%
# Answer "True" or "False" in the space provided for each of the questions
# Example:
# Example question: Is ECE 27000 the best class?
example_answer= "True"

# Q1: The instructors have no way to check if I bought food and drinks into the lab if I bring them in outside my scheduled lab section.
question_1= "False"

# Q2: Lab equipment can be removed from the lab.
question_2= "False"

# Q3: It is okay to share my lab kit/AD2 with a friend who may need it.
question_3= "False"

# Q4: I must log off the lab machine when I am done using it. Leaving my user account logged in will result in a lab penalty.
question_4= "True"

# Q5: Appropriate documentation must always be included with a request for a lab extension, if requested.
question_5= "True"

# Q6: If I bring liquids or food to the lab, I will receive a lab penalty on my lab for that week.
question_6= "True"

# Q7: My first point of contact regarding clarifications about the grade I received should be one of the TAs for my section.
question_7= "True"

# Q8: I should clean my lab station once I am done with the lab. Loose wires or components on the lab bench will result in a lab penalty.
question_8= "True"

# Q9: If I notice equipment failure, I should attempt to fix it myself.
question_9= "False"

# Q10: It is okay for me to have a closed water bottle or unopened cans at my lab station.
question_10= "False"

# %% [markdown]
# ## Additional Information
#
# Please share one thing you hope to learn in this course.

# %%
learning_goal = "How to design and check mircochips and microcircuits" # What you hope to learn in this course

# %% [markdown]
# # What file do you submit for each Lab Assignment?
# **[Note: This format applies to all lab assignments!]**
#
# By now, you should have answered all the questions above, replacing every `STUDENT_ANSWER_HERE` with your answer. Next, you will **generate a file called `student_submission.json`**, which will contain all your answers.
#
# ## How to generate __student_submission.json__:
#
# 1. Open your `.ipynb` file.
# 2. Click **Run All** to execute all cells.
#    - (If you are unsure where or what “Run All” is, refer to *Setup for Your First Lab Assignment* in `lab0.md`.)
# 3. After running all cells, the notebook will produce a `student_submission.json` file containing all your answers.
#
# Once you have your `student_submission.json`, go back to the lab document and read the **Submission Instructions** section, which explains exactly **how and where to submit this file**.
#
# > **Note:** Every lab document will include a **Submission Instructions** section at the end. You are expected to read this section for each lab to ensure you submit correctly (e.g., `lab0.md`).

# %% [markdown]
# ## Important Note
#
# This notebook shows the format you will use for all lab submissions in this course. Always:
# 1. Fill in your answers in the code cells provided
# 2. Do not modify the code that generates the JSON file at the end
# 3. Submit the completed notebook file as instructed
# 4. Make sure to run all cells before submission

# %%
# Do not under any circumstances edit this cell you will recieve a ZERO!
import json

# Collect all variables for submission
variables = [
    username,
    name,
    colorblind,
    left_handed_desk,
    learning_goal,
    question_1,
    question_2,
    question_3,
    question_4,
    question_5,
    question_6,
    question_7,
    question_8,
    question_9,
    question_10
]

# Create a dictionary with variable names and values
variables_dict = {var_name: var_value for var_name, var_value in zip([
    'username', 'name', 'colorblind', 'left_handed_desk', 'learning_goal',
    'question_1', 'question_2', 'question_3', 'question_4', 'question_5',
    'question_6', 'question_7', 'question_8', 'question_9', 'question_10',
], variables)}

# Save to JSON file
try:
    with open('student_submission.json', 'w') as f:
        json.dump(variables_dict, f, indent=4)
except Exception as e:
    print("Double check your current working directory is the same location where your .ipynb is")
    print(e)

# Show the data that will be submitted
print("The following information will be submitted:")
print(json.dumps(variables_dict, indent=4))
# Out:
# The following information will be submitted:
# {
#     "username": "akatreka",
#     "name": "Arush Rahul Katrekar",
#     "colorblind": "No",
#     "left_handed_desk": "No",
#     "learning_goal": "How to design and check mircochips and microcircuits",
#     "question_1": "False",
#     "question_2": "False",
#     "question_3": "False",
#     "question_4": "True",
#     "question_5": "True",
#     "question_6": "True",
#     "question_7": "True",
#     "question_8": "True",
#     "question_9": "False",
#     "question_10": "False"
# }

# %% [markdown]
# <!--
# attention_block
# <span style="text-align: center">
# <span style="color: red; font-weight: 700; font-size: xx-large">STOP.</span>
#
# This is an example of a note designed to get your attention. If you see this, read it carefully.
#
# Some of you may have come directly to this lab without starting on <a href="../../submit/?item=hw0">homework 0</a>. You need to finish that first before completing any of the subsequent lab assignments.
# </span>
# -->
